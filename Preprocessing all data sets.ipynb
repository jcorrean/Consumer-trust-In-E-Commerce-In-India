# %%
import pandas as pd

# %%
mobile1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/1_Mobiles/1.xlsx")
mobile2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/1_Mobiles/2.xlsx")
mobile3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/1_Mobiles/3.xlsx")
mobile4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/1_Mobiles/4.xlsx")
mobile5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/1_Mobiles/5.xlsx")

# %%
mobiles = [mobile1, mobile2, mobile3, mobile4, mobile5]

# %%
Mobiles = pd.concat(mobiles, ignore_index=True)
Mobiles.tail()
# Out:
#       Rating            Heading  \
# 2409       5  Terrific purchase
# 2410       4    Value-for-money
# 2411       5     Simply awesome
# 2412       5     Simply awesome
# 2413       5             Super!
#
#                                         Detailed_review  \
# 2409  Using this product from 3 weeks...no lag, no h...
# 2410                       Overall good phone,READ MORE
# 2411                             Nice product,READ MORE
# 2412                          Worth for money,READ MORE
# 2413                                     Cool,READ MORE
#
#                          Name          Time  Upvotes  Downvotes
# 2409        Flipkart Customer  2 months ago        1          0
# 2410                  Rishabh  2 months ago        1          0
# 2411          Mani  Maniroyal  2 months ago        1          0
# 2412  Sashibhusan Baliarsingh  2 months ago        1          1
# 2413            ABHISHEK  AD   2 months ago        1          0

# %%
laptop1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/2_Laptops/6.xlsx")
laptop2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/2_Laptops/7.xlsx")
laptop3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/2_Laptops/8.xlsx")
laptop4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/2_Laptops/9.xlsx")
laptop5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/2_Laptops/10.xlsx")

# %%
laptops = [laptop1, laptop2, laptop3, laptop4, laptop5]
Laptops = pd.concat(laptops, ignore_index = True)
Laptops.tail()
# Out:
#       Rating                Heading  \
# 1735       5      Worth every penny
# 1736       5              Fabulous!
# 1737       4           Nice product
# 1738       5  Mind-blowing purchase
# 1739       4              Very Good
#
#                                         Detailed_review               Name  \
# 1735  I am using  last one month it is working very ...      ramesh tholam
# 1736                             Good product,READ MORE  Gudipalli Francis
# 1737  Everything is fine with the laptop. It's fast ...       Subodh Kumar
# 1738                            Good products,READ MORE      Basar  Mondal
# 1739  Overall good buy under 55k.,Pros. ,1. The batt...      Nikhil Shukla
#
#              Time  Upvotes  Downvotes
# 1735  1 month ago        0          0
# 1736  1 month ago        0          0
# 1737  1 month ago        0          0
# 1738  1 month ago        0          0
# 1739  1 month ago        0          0

# %%
sports1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/3_Sports/11.xlsx")
sports2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/3_Sports/12.xlsx")
sports3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/3_Sports/13.xlsx")
sports4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/3_Sports/14.xlsx")
sports5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/3_Sports/15.xlsx")

# %%
sports = [sports1, sports2, sports3, sports4, sports5]
Sports = pd.concat(sports, ignore_index = True)
Sports.tail()
# Out:
#       Rating         Heading                          Detailed_review  \
# 2040       5   Great product  Very nice and lovely football,READ MORE
# 2041       5       Fabulous!                           Good,READ MORE
# 2042       5       Brilliant                      wonderful,READ MORE
# 2043       5       Fabulous!  very good product...I love it,READ MORE
# 2044       5  Simply awesome                             Ok,READ MORE
#
#                    Name          Time  Upvotes  Downvotes
# 2040      Ayush  Mouni      May, 2020        3          2
# 2041      Shankar Adhav     Feb, 2020        3          2
# 2042   Lakhindar Hansda     Dec, 2019        3          2
# 2043  Flipkart Customer     Oct, 2019        3          2
# 2044  Flipkart Customer  5 months ago        6         10

# %%
bottle1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/4_Bottles/16.xlsx")
bottle2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/4_Bottles/17.xlsx")
bottle3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/4_Bottles/18.xlsx")
bottle4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/4_Bottles/19.xlsx")
bottle5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/4_Bottles/20.xlsx")

# %%
bottles = [bottle1, bottle2, bottle3, bottle4, bottle5]
Bottles = pd.concat(bottles, ignore_index = True)
Bottles.tail()
# Out:
#       Rating              Heading  \
# 2536       5    Terrific purchase
# 2537       4          Good choice
# 2538       2     Terrible product
# 2539       5  Best in the market!
# 2540       5   Highly recommended
#
#                                         Detailed_review                 Name  \
# 2536  Cheap and best Copper water bottle, its leakag...   TARUN KUMAR PODDAR
# 2537                                    Good.,READ MORE            Rantu Dey
# 2538                             Quality poor,READ MORE         Veera Pujala
# 2539                                       Ok,READ MORE          vivek vivek
# 2540                    Good, value for money,READ MORE  Beenaveni  Srikanth
#
#               Time  Upvotes  Downvotes
# 2536  4 months ago        0          0
# 2537  4 months ago        0          0
# 2538  4 months ago        0          0
# 2539  4 months ago        0          0
# 2540  4 months ago        0          0

# %%
baby1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/5_Baby Products/21.xlsx")
baby2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/5_Baby Products/22.xlsx")
baby3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/5_Baby Products/23.xlsx")
baby4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/5_Baby Products/24.xlsx")
baby5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/5_Baby Products/25.xlsx")

# %%
baby = [baby1, baby2, baby3, baby4, baby5]
Baby = pd.concat(baby, ignore_index = True)
Baby.tail()
# Out:
#       Rating             Heading  \
# 2401       5           Excellent
# 2402       5    Perfect product!
# 2403       5      Simply awesome
# 2404       4         Good choice
# 2405       5  Highly recommended
#
#                                         Detailed_review                  Name  \
# 2401                              Good Paking,READ MORE          Atul  Kumar
# 2402                                     Nice,READ MORE             Nimai Das
# 2403                                     Good,READ MORE           Ramakrishna
# 2404                             Good product,READ MORE           Sumit Verma
# 2405  Good product and lesser than market price👍,REA...  Anandhan  Muthusamy
#
#              Time  Upvotes  Downvotes
# 2401  1 month ago        0          0
# 2402  1 month ago        0          0
# 2403  1 month ago        0          0
# 2404  1 month ago        0          0
# 2405  1 month ago        0          0

# %%
tool1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/6_Tools/26.xlsx")
tool2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/6_Tools/27.xlsx")
tool3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/6_Tools/28.xlsx")
tool4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/6_Tools/29.xlsx")
tool5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/6_Tools/30.xlsx")

# %%
tool = [tool1, tool2, tool3, tool4, tool5]
Tool = pd.concat(tool, ignore_index = True)
Tool.tail()
# Out:
#       Rating         Heading  \
# 2370       5       Wonderful
# 2371       3  Decent product
# 2372       5       Brilliant
# 2373       2        Not good
# 2374       5       Excellent
#
#                                         Detailed_review  \
# 2370                                     good,READ MORE
# 2371                            nice  product,READ MORE
# 2372            good working conditions nice.,READ MORE
# 2373  bad quality .. dont tight properly .. dont buy...
# 2374  Very nice and efficient product as expected fr...
#
#                         Name       Time  Upvotes  Downvotes
# 2370             Suvendu Kar  Oct, 2018        0          0
# 2371           Hardeep Singh  Sep, 2018        0          0
# 2372             Ashok Kumar  Sep, 2018        0          0
# 2373           Gaurav Ajmera  Sep, 2018        0          2
# 2374  Rajarshi Chattopadhyay  Sep, 2018        0          0

# %%
gym1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/7_Gym/31.xlsx")
gym2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/7_Gym/32.xlsx")
gym3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/7_Gym/33.xlsx")
gym4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/7_Gym/34.xlsx")
gym5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/7_Gym/35.xlsx")

# %%
gym = [gym1, gym2, gym3, gym4, gym5]
Gym = pd.concat(gym, ignore_index = True)
Gym.tail()
# Out:
#       Rating              Heading  \
# 2337       1            Worthless
# 2338       1      Useless product
# 2339       5  Best in the market!
# 2340       1            Very poor
# 2341       4           Delightful
#
#                                    Detailed_review                     Name  \
# 2337  Colour faid .....,Not good ,👎👎👎👎👎👎,READ MORE           ANUJ SRIVASTAV
# 2338                        bad material,READ MORE  Varnisha.T Thiyagarajan
# 2339                        Nice product,READ MORE        Flipkart Customer
# 2340                Bad material quality,READ MORE                   Shashi
# 2341                        Good product,READ MORE              Rijuan Rose
#
#               Time  Upvotes  Downvotes
# 2337  3 months ago        0          0
# 2338  3 months ago        0          0
# 2339  3 months ago        0          0
# 2340  3 months ago        0          0
# 2341  3 months ago        0          0

# %%
book1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/8_Books/36.xlsx")
book2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/8_Books/37.xlsx")
book3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/8_Books/38.xlsx")
book4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/8_Books/39.xlsx")
book5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/8_Books/40.xlsx")

# %%
books = [book1, book2, book3, book4, book5]
Books = pd.concat(books, ignore_index = True)
Books.tail()
# Out:
#       Rating                Heading  \
# 2344       5      Worth every penny
# 2345       5      Terrific purchase
# 2346       5  Mind-blowing purchase
# 2347       5    Best in the market!
# 2348       5                 Super!
#
#                                         Detailed_review             Name  \
# 2344                              to good ...,READ MORE  WASIM  MOHAMMAD
# 2345                                  perfect,READ MORE  Sushmita Biswas
# 2346        well packed & such a great book 😊,READ MORE     AMIT KASHYAP
# 2347  Delivery within 24 hours!,Updated Books! ,Good...      Somnath Sen
# 2348  It was my first book.Honestly i didnt expect i...   Gaurav  Mandal
#
#            Time  Upvotes  Downvotes
# 2344  Oct, 2018        1          0
# 2345  Oct, 2018        1          0
# 2346  Oct, 2018        1          0
# 2347  Aug, 2018        1          0
# 2348  Jul, 2018        1          0

# %%
groceries1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/9_Groceries/41.xlsx")
groceries2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/9_Groceries/42.xlsx")
groceries3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/9_Groceries/43.xlsx")
groceries4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/9_Groceries/44.xlsx")
groceries5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/9_Groceries/45.xlsx")

# %%
groceries = [groceries1, groceries2, groceries3, groceries4, groceries5]
Groceries = pd.concat(groceries, ignore_index = True)
Groceries.tail()
# Out:
#       Rating            Heading  \
# 1812       4          Very Good
# 1813       4    Value-for-money
# 1814       5  Terrific purchase
# 1815       5          Wonderful
# 1816       4    Worth the money
#
#                                         Detailed_review  \
# 1812                                     Good,READ MORE
# 1813  original product ..nice bottle..thankyou filpk...
# 1814                           Good product 👍,READ MORE
# 1815                                     Good,READ MORE
# 1816                                    Happy,READ MORE
#
#                             Name         Time  Upvotes  Downvotes
# 1812  Naga venkateswararao  Goli  10 days ago        0          0
# 1813                  Asha Rawat  10 days ago        0          0
# 1814           Flipkart Customer  10 days ago        0          0
# 1815                  Md Huzaifa  11 days ago        0          0
# 1816           Flipkart Customer  11 days ago        0          0

# %%
home1 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/10_Home Furnishing/46.xlsx")
home2 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/10_Home Furnishing/47.xlsx")
home3 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/10_Home Furnishing/48.xlsx")
home4 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/10_Home Furnishing/49.xlsx")
home5 = pd.read_excel("/home/jc/Documents/GitHub/Consumer-trust-In-E-Commerce-In-India/Data/Raw/Categories/10_Home Furnishing/50.xlsx")

# %%
home = [home1, home2, home3, home4, home5]
Homes = pd.concat(home, ignore_index = True)
Homes.tail()
# Out:
#       Rating            Heading  \
# 2127       2           Not good
# 2128       5  Terrific purchase
# 2129       4          Wonderful
# 2130       2     Unsatisfactory
# 2131       5          Excellent
#
#                                         Detailed_review               Name  \
# 2127  It went flat in less than a month. Not good qu...        Camie Camie
# 2128  Good quality pillows writing this review after...    Sricharan Gunda
# 2129  Pillows are of great quality, very soft and fl...              Ankit
# 2130  The product is not even foamy.its just like a ...  Flipkart Customer
# 2131  Package was good.pillows are packed in the box...  Flipkart Customer
#
#               Time  Upvotes  Downvotes
# 2127  6 months ago        0          0
# 2128  6 months ago        1          0
# 2129  6 months ago        1          0
# 2130  7 months ago        1          0
# 2131  8 months ago        1          0

# %%
items = [Mobiles, Laptops, Sports, Bottles, Baby, Tool, Gym, Books, Groceries, Homes]
Items = pd.concat(items, ignore_index = True)
Items.tail()
# Out:
#        Rating            Heading  \
# 22156       2           Not good
# 22157       5  Terrific purchase
# 22158       4          Wonderful
# 22159       2     Unsatisfactory
# 22160       5          Excellent
#
#                                          Detailed_review               Name  \
# 22156  It went flat in less than a month. Not good qu...        Camie Camie
# 22157  Good quality pillows writing this review after...    Sricharan Gunda
# 22158  Pillows are of great quality, very soft and fl...              Ankit
# 22159  The product is not even foamy.its just like a ...  Flipkart Customer
# 22160  Package was good.pillows are packed in the box...  Flipkart Customer
#
#                Time  Upvotes  Downvotes
# 22156  6 months ago        0          0
# 22157  6 months ago        1          0
# 22158  6 months ago        1          0
# 22159  7 months ago        1          0
# 22160  8 months ago        1          0

# %%
cond1 = Items["Upvotes"] != 0
cond2 = Items["Downvotes"] != 0
Valid_items = Items[cond1 & cond2]
Valid_items.tail()
# Out:
#        Rating                           Heading  \
# 22077       5  Awesome Product and best pricing
# 22078       1         Did not meet expectations
# 22079       1                   Useless product
# 22080       3                         Just okay
# 22126       4                      Nice product
#
#                                          Detailed_review              Name  \
# 22077  Its soft and comfortable, neither too thick no...      Aditya Singh
# 22078  I got only one pillow. which is not even close...      Nikhil Gupta
# 22079  It is a complete polyester pillow with polyest...  Srihari Kurupath
# 22080  Nice one for this price ,Fiber quantity is poo...        Akhil  C k
# 22126                             Nice product,READ MORE      Saroj pandey
#
#             Time  Upvotes  Downvotes
# 22077  Jan, 2017        3          3
# 22078  Oct, 2018        4          6
# 22079  Jul, 2019        2          2
# 22080  Mar, 2019        2          2
# ...

# %%
Valid_items['Satisfaction Ratio'] =(Valid_items['Upvotes'])/(Valid_items['Upvotes']+Valid_items['Downvotes'])
Valid_items.tail()
# Out:
# /tmp/ipykernel_36225/7101469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Valid_items['Satisfaction Ratio'] =(Valid_items['Upvotes'])/(Valid_items['Upvotes']+Valid_items['Downvotes'])
#        Rating                           Heading  \
# 22077       5  Awesome Product and best pricing
# 22078       1         Did not meet expectations
# 22079       1                   Useless product
# 22080       3                         Just okay
# 22126       4                      Nice product
#
#                                          Detailed_review              Name  \
# 22077  Its soft and comfortable, neither too thick no...      Aditya Singh
# 22078  I got only one pillow. which is not even close...      Nikhil Gupta
# ...

# %%
Valid_items.to_csv("ValidItems.csv")

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(Valid_items['Satisfaction Ratio'])
# Out:
# (array([ 21.,  57., 122.,  91., 582., 211., 552., 796., 612., 210.]),
#  array([0.07377049, 0.16463906, 0.25550762, 0.34637619, 0.43724475,
#         0.52811332, 0.61898188, 0.70985045, 0.80071901, 0.89158758,
#         0.98245614]),
#  <BarContainer object of 10 artists>)
